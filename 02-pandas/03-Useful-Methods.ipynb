# %% [markdown]
# # Useful Methods
#
# Let's cover some useful methods and functions built in to pandas. This is actually just a small sampling of the functions and methods available in Pandas, but they are some of the most commonly used.
# The [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) is a great resource to continue exploring more methods and functions (we will introduce more further along in the course).
# Here is a list of functions and methods we'll cover here (click on one to jump to that section in this notebook.):
#
# * [apply() method](#apply_method)
# * [apply() with a function](#apply_function)
# * [apply() with a lambda expression](#apply_lambda)
# * [apply() on multiple columns](#apply_multiple)
# * [describe()](#describe)
# * [sort_values()](#sort)
# * [corr()](#corr)
# * [idxmin and idxmax](#idx)
# * [value_counts](#v_c)
# * [replace](#replace)
# * [unique and nunique](#uni)
# * [map](#map)
# * [duplicated and drop_duplicates](#dup)
# * [between](#bet)
# * [sample](#sample)
# * [nlargest](#n)

# %% [markdown]
# <a id='apply_method'></a>
#
# ## The .apply() method
#
# Here we will learn about a very useful method known as **apply** on a DataFrame. This allows us to apply and broadcast custom functions on a DataFrame column

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.shape
# Out:
# (244, 11)

# %% [markdown]
# <a id='apply_function'></a>
# ### apply with a function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
def last_four(num):
    return str(num)[-4:]

# %%
type(3560325168603410)
# Out:
# int

# %%
str(3560325168603410)[12:]
# Out:
# '3410'

# %%
str(3560325168603410)[-4:]
# Out:
# '3410'

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['CC Number']
# Out:
# 0      3560325168603410
# 1      4478071379779230
# 2      6011812112971322
# 3      4676137647685994
# 4      4832732618637221
#              ...
# 239    5296068606052842
# 240    3506806155565404
# 241    6011891618747196
# 242       4375220550950
# 243    3511451626698139
# Name: CC Number, Length: 244, dtype: int64

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410    Sun2959      3410
# 1      Douglas Tucker  4478071379779230    Sun4608      9230
# 2      Travis Walters  6011812112971322    Sun4458      1322
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994
# 4        Tonya Carter  4832732618637221    Sun2251      7221

# %%
df['Payment ID'] = df['Payment ID'].apply(last_four)

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four
# 0  Christy Cunningham  3560325168603410       2959      3410
# 1      Douglas Tucker  4478071379779230       4608      9230
# 2      Travis Walters  6011812112971322       4458      1322
# 3    Nathaniel Harris  4676137647685994       5260      5994
# 4        Tonya Carter  4832732618637221       2251      7221

# %% [markdown]
# ### Using .apply() with more complex functions

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df.head(15)
# Out:
#     total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 12       15.42  1.57    Male     No  Sun  Dinner     2              7.71
# 13       18.43  3.00    Male     No  Sun  Dinner     4              4.61
# 14       14.83  3.02  Female     No  Sun  Dinner     2              7.42
#
#             Payer Name         CC Number Payment ID last_four yelp
# 0   Christy Cunningham  3560325168603410       2959      3410   $$
# 1       Douglas Tucker  4478071379779230       4608      9230   $$
# 2       Travis Walters  6011812112971322       4458      1322   $$
# 3     Nathaniel Harris  4676137647685994       5260      5994   $$
# 4         Tonya Carter  4832732618637221       2251      7221   $$
# 5           Erik Smith   213140353657882       9679      7882   $$
# 6   Kristopher Johnson  2223727524230344       5985      0344    $
# 7          Robert Buck  3514785077705092       8157      5092   $$
# 8      Joseph Mcdonald  3522866365840377       6820      0377   $$
# 9        Jerome Abbott  3532124519049786       3775      9786   $$
# 10       William Riley      566287581219       2546      1219   $$
# 11        Diane Macias  4577817359320969       6686      0969  $$$
# 12     Chad Harrington      577040572932       1300      2932   $$
# 13        Joshua Jones  6011163105616890       2971      6890   $$
# 14       Vanessa Jones    30016702287574       3848      7574   $$

# %% [markdown]
# <a id='apply_lambda'></a>
# ### apply with lambda

# %%
def simple(num):
    return num*2

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
16.99*0.18
# Out:
# 3.0582

# %%
df['total_bill'].apply(lambda bill:bill*0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID last_four yelp
# 0  Christy Cunningham  3560325168603410       2959      3410   $$
# 1      Douglas Tucker  4478071379779230       4608      9230   $$

# %%
df = df.drop(['last_four','yelp'],axis=1)

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608

# %% [markdown]
# <a id='apply_multiple'></a>
# ## apply that uses multiple columns
#
# Note, there are several ways to do this:
#
# https://stackoverflow.com/questions/19914937/applying-function-with-multiple-arguments-to-create-a-new-pandas-column

# %%
df.head(3)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608
# 2      Travis Walters  6011812112971322       4458

# %%
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
#

# def quality(total_bill,tip):
#     return "Generous" if tip/total_bill>0.25 else "Other" # Ternary Operator

# %%
df[['total_bill','tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
# To understand what is happening internally
# df[['total_bill','tip']]
# df[['total_bill','tip']].head(10)
# df[['total_bill','tip']].head(4).apply(lambda df:print(df),axis=1)
# df[['total_bill','tip']].head(4).apply(lambda df:print(df["total_bill"],df["tip"]),axis=1)


# df[['total_bill','tip']]
# df[['total_bill','tip']].head()
# df[['total_bill','tip']].head()['total_bill']
# df[['total_bill','tip']].head()['tip']

# %%
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df.tail(15)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID Tip Quality
# 229  Jennifer Russell     4793003293608       3943       Other
# 230   Michael Osborne     4258682154026       7872       Other
# 231       Jason Parks     4812333796161       6334       Other
# 232      James Taylor  6011482917327995       2124    Generous
# 233        Paul Novak  6011698897610858       1467       Other
# 234     Tracy Douglas  4097938155941930       7220       Other
# 235     Sean Gonzalez  3534021246117605       4615       Other
# 236     Matthew Myers  3543676378973965       5032       Other
# 237      Thomas Brown  4284722681265508       2929       Other
# 238    Kimberly Crane      676184013727       9777       Other
# 239     Michael Avila  5296068606052842       2657       Other
# 240    Monica Sanders  3506806155565404       1766       Other
# 241        Keith Wong  6011891618747196       3880       Other
# 242      Dennis Dixon     4375220550950       at17       Other
# 243   Michelle Hardin  3511451626698139       r672       Other

# %%
df['Tip Quality 2'] = df[['total_bill','tip']].apply(lambda df: "Generous" if df['tip']/df['total_bill']>0.25 else "Other",axis=1)

# %%
df.tail(15)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID Tip Quality Tip Quality 2
# 229  Jennifer Russell     4793003293608       3943       Other         Other
# 230   Michael Osborne     4258682154026       7872       Other         Other
# 231       Jason Parks     4812333796161       6334       Other         Other
# 232      James Taylor  6011482917327995       2124    Generous      Generous
# 233        Paul Novak  6011698897610858       1467       Other         Other
# 234     Tracy Douglas  4097938155941930       7220       Other         Other
# 235     Sean Gonzalez  3534021246117605       4615       Other         Other
# 236     Matthew Myers  3543676378973965       5032       Other         Other
# 237      Thomas Brown  4284722681265508       2929       Other         Other
# 238    Kimberly Crane      676184013727       9777       Other         Other
# 239     Michael Avila  5296068606052842       2657       Other         Other
# 240    Monica Sanders  3506806155565404       1766       Other         Other
# 241        Keith Wong  6011891618747196       3880       Other         Other
# 242      Dennis Dixon     4375220550950       at17       Other         Other
# 243   Michelle Hardin  3511451626698139       r672       Other         Other

# %%
import numpy as np

# %%
df['Tip Quality 3'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.tail(15)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID Tip Quality Tip Quality 2  \
# 229  Jennifer Russell     4793003293608       3943       Other         Other
# 230   Michael Osborne     4258682154026       7872       Other         Other
# 231       Jason Parks     4812333796161       6334       Other         Other
# 232      James Taylor  6011482917327995       2124    Generous      Generous
# 233        Paul Novak  6011698897610858       1467       Other         Other
# 234     Tracy Douglas  4097938155941930       7220       Other         Other
# 235     Sean Gonzalez  3534021246117605       4615       Other         Other
# 236     Matthew Myers  3543676378973965       5032       Other         Other
# 237      Thomas Brown  4284722681265508       2929       Other         Other
# 238    Kimberly Crane      676184013727       9777       Other         Other
# 239     Michael Avila  5296068606052842       2657       Other         Other
# 240    Monica Sanders  3506806155565404       1766       Other         Other
# 241        Keith Wong  6011891618747196       3880       Other         Other
# 242      Dennis Dixon     4375220550950       at17       Other         Other
# 243   Michelle Hardin  3511451626698139       r672       Other         Other
#
#     Tip Quality 3
# 229         Other
# 230         Other
# 231         Other
# 232      Generous
# 233         Other
# 234         Other
# 235         Other
# 236         Other
# 237         Other
# 238         Other
# 239         Other
# 240         Other
# 241         Other
# 242         Other
# 243         Other

# %% [markdown]
# Wow! Vectorization is much faster! Keep **np.vectorize()** in mind for the future.
#
# Full Details:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.vectorize.html

# %% [markdown]
# <a id='describe'></a>
# ### df.describe for statistical summaries

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality Tip Quality 2  \
# 0  Christy Cunningham  3560325168603410       2959       Other         Other
# 1      Douglas Tucker  4478071379779230       4608       Other         Other
# 2      Travis Walters  6011812112971322       4458       Other         Other
# 3    Nathaniel Harris  4676137647685994       5260       Other         Other
# 4        Tonya Carter  4832732618637221       2251       Other         Other
#
#   Tip Quality 3
# 0         Other
# 1         Other
# 2         Other
# 3         Other
# 4         Other

# %%
df = df.drop(['Tip Quality 2', 'Tip Quality 3'],axis=1)

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410       2959       Other
# 1      Douglas Tucker  4478071379779230       4608       Other
# 2      Travis Walters  6011812112971322       4458       Other
# 3    Nathaniel Harris  4676137647685994       5260       Other
# 4        Tonya Carter  4832732618637221       2251       Other

# %% [markdown]
# <a id='sort'></a>
# ### sort_values()

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip  gender smoker   day    time  size  price_per_person  \
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID Tip Quality
# 92         Leah Ramirez  3508911676966392       3780       Other
# 111         Terri Jones  3559221007826887       4801       Other
# 67        Tiffany Brock  4359488526995267       3455    Generous
# 236       Matthew Myers  3543676378973965       5032       Other
# 0    Christy Cunningham  3560325168603410       2959       Other
# ..                  ...               ...        ...         ...
# 141      Steven Carlson  3526515703718508       1025       Other
# 59          Brian Ortiz  6596453823950595       8139       Other
# 23       Lance Peterson  3542584061609808       t239       Other
# 212     Alex Williamson      676218815212       4590       Other
# 170       Gregory Clark  5473850968388236       1954       Other
#
# [244 rows x 12 columns]

# %%
df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip  gender smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
#
#              Payer Name         CC Number Payment ID Tip Quality
# 170       Gregory Clark  5473850968388236       1954       Other
# 212     Alex Williamson      676218815212       4590       Other
# 23       Lance Peterson  3542584061609808       t239       Other
# 59          Brian Ortiz  6596453823950595       8139       Other
# 141      Steven Carlson  3526515703718508       1025       Other
# ..                  ...               ...        ...         ...
# 0    Christy Cunningham  3560325168603410       2959       Other
# 111         Terri Jones  3559221007826887       4801       Other
# 92         Leah Ramirez  3508911676966392       3780       Other
# 67        Tiffany Brock  4359488526995267       3455    Generous
# 236       Matthew Myers  3543676378973965       5032       Other
#
# [244 rows x 12 columns]

# %%
# Helpful if you want to reorder after a sort
# https://stackoverflow.com/questions/13148429/how-to-change-the-order-of-dataframe-columns
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip  gender smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID Tip Quality
# 67        Tiffany Brock  4359488526995267       3455    Generous
# 111         Terri Jones  3559221007826887       4801       Other
# 92         Leah Ramirez  3508911676966392       3780       Other
# 236       Matthew Myers  3543676378973965       5032       Other
# 0    Christy Cunningham  3560325168603410       2959       Other
# ..                  ...               ...        ...         ...
# 141      Steven Carlson  3526515703718508       1025       Other
# 59          Brian Ortiz  6596453823950595       8139       Other
# 23       Lance Peterson  3542584061609808       t239       Other
# 212     Alex Williamson      676218815212       4590       Other
# 170       Gregory Clark  5473850968388236       1954       Other
#
# [244 rows x 12 columns]

# %%
df.sort_values(['tip','size'],ascending=False) # descending order
# Out:
#      total_bill    tip  gender smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
#
#              Payer Name         CC Number Payment ID Tip Quality
# 170       Gregory Clark  5473850968388236       1954       Other
# 212     Alex Williamson      676218815212       4590       Other
# 23       Lance Peterson  3542584061609808       t239       Other
# 59          Brian Ortiz  6596453823950595       8139       Other
# 141      Steven Carlson  3526515703718508       1025       Other
# ..                  ...               ...        ...         ...
# 0    Christy Cunningham  3560325168603410       2959       Other
# 92         Leah Ramirez  3508911676966392       3780       Other
# 236       Matthew Myers  3543676378973965       5032       Other
# 67        Tiffany Brock  4359488526995267       3455    Generous
# 111         Terri Jones  3559221007826887       4801       Other
#
# [244 rows x 12 columns]

# %% [markdown]
# <a id='corr'></a>
# ## df.corr() for correlation checks
#
# [Wikipedia on Correlation](https://en.wikipedia.org/wiki/Correlation_and_dependence)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
#  11  Tip Quality       244 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 23.0+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill','tip','size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality
# 0  Christy Cunningham  3560325168603410       2959       Other
# 1      Douglas Tucker  4478071379779230       4608       Other
# 2      Travis Walters  6011812112971322       4458       Other
# 3    Nathaniel Harris  4676137647685994       5260       Other
# 4        Tonya Carter  4832732618637221       2251       Other

# %%
df = df.drop(['Tip Quality'],axis=1)

# %%
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608

# %% [markdown]
# <a id='idx'></a>
# ### idxmin and idxmax

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608
# 2      Travis Walters  6011812112971322       4458
# 3    Nathaniel Harris  4676137647685994       5260
# 4        Tonya Carter  4832732618637221       2251

# %%
df['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
max_total_bill = df['total_bill'].max()
print(max_total_bill)
# Out:
# 50.81

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df.iloc[169:172]
# Out:
#      total_bill    tip  gender smoker  day    time  size  price_per_person  \
# 169       10.63   2.00  Female    Yes  Sat  Dinner     2              5.32
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 171       15.81   3.16    Male    Yes  Sat  Dinner     2              7.90
#
#         Payer Name         CC Number Payment ID
# 169       Amy Hill  3536332481454019       1788
# 170  Gregory Clark  5473850968388236       1954
# 171     David Hall      502004138207       6750

# %%
df.iloc[df['total_bill'].idxmax()]
# Out:
# total_bill                     50.81
# tip                             10.0
# gender                          Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                      1954
# Name: 170, dtype: object

# %%
df['total_bill'].min()
# Out:
# np.float64(3.07)

# %%
df['total_bill'].idxmin() # Index location
# Out:
# 67

# %%
df.iloc[65:70]
# Out:
#     total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 65       20.08  3.15    Male     No  Sat  Dinner     3              6.69
# 66       16.45  2.47  Female     No  Sat  Dinner     2              8.22
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 68       20.23  2.01    Male     No  Sat  Dinner     2             10.12
# 69       15.01  2.09    Male    Yes  Sat  Dinner     2              7.50
#
#                Payer Name         CC Number Payment ID
# 65           Justin Dixon   180021262464926       6840
# 66          Rachel Vaughn  3569262692675583       4750
# 67          Tiffany Brock  4359488526995267       3455
# 68  Mr. Travis Bailey Jr.       60406789937       t561
# 69              Adam Hall  4700924377057571       t855

# %%
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# gender                        Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                      3455
# Name: 67, dtype: object

# %%
df.iloc[df['total_bill'].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# gender                        Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                      3455
# Name: 67, dtype: object

# %% [markdown]
# <a id='v_c'></a>
# ### value_counts
#
# Nice method to quickly get a count per category. Only makes sense on categorical columns.

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608
# 2      Travis Walters  6011812112971322       4458
# 3    Nathaniel Harris  4676137647685994       5260
# 4        Tonya Carter  4832732618637221       2251

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %% [markdown]
# <a id='replace'></a>
#
# ### replace
#
# Quickly replace values with another one.

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410       2959
# 1      Douglas Tucker  4478071379779230       4608
# 2      Travis Walters  6011812112971322       4458
# 3    Nathaniel Harris  4676137647685994       5260
# 4        Tonya Carter  4832732618637221       2251

# %%
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.tail(15)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID Tip Quality
# 229  Jennifer Russell     4793003293608       3943       Other
# 230   Michael Osborne     4258682154026       7872       Other
# 231       Jason Parks     4812333796161       6334       Other
# 232      James Taylor  6011482917327995       2124    Generous
# 233        Paul Novak  6011698897610858       1467       Other
# 234     Tracy Douglas  4097938155941930       7220       Other
# 235     Sean Gonzalez  3534021246117605       4615       Other
# 236     Matthew Myers  3543676378973965       5032       Other
# 237      Thomas Brown  4284722681265508       2929       Other
# 238    Kimberly Crane      676184013727       9777       Other
# 239     Michael Avila  5296068606052842       2657       Other
# 240    Monica Sanders  3506806155565404       1766       Other
# 241        Keith Wong  6011891618747196       3880       Other
# 242      Dennis Dixon     4375220550950       at17       Other
# 243   Michelle Hardin  3511451626698139       r672       Other

# %%
df['Tip Quality'].value_counts()
# Out:
# Tip Quality
# Other       234
# Generous     10
# Name: count, dtype: int64

# %%
df['Tip Quality'].replace(to_replace='Other',value='Ok')
# Out:
# 0      Ok
# 1      Ok
# 2      Ok
# 3      Ok
# 4      Ok
#        ..
# 239    Ok
# 240    Ok
# 241    Ok
# 242    Ok
# 243    Ok
# Name: Tip Quality, Length: 244, dtype: object

# %%
df['Tip Quality'] = df['Tip Quality'].replace(to_replace=['Other','other','OTHER'],value='Ok')

# %%
df.tail(15)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4              6.00
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#            Payer Name         CC Number Payment ID Tip Quality
# 229  Jennifer Russell     4793003293608       3943          Ok
# 230   Michael Osborne     4258682154026       7872          Ok
# 231       Jason Parks     4812333796161       6334          Ok
# 232      James Taylor  6011482917327995       2124    Generous
# 233        Paul Novak  6011698897610858       1467          Ok
# 234     Tracy Douglas  4097938155941930       7220          Ok
# 235     Sean Gonzalez  3534021246117605       4615          Ok
# 236     Matthew Myers  3543676378973965       5032          Ok
# 237      Thomas Brown  4284722681265508       2929          Ok
# 238    Kimberly Crane      676184013727       9777          Ok
# 239     Michael Avila  5296068606052842       2657          Ok
# 240    Monica Sanders  3506806155565404       1766          Ok
# 241        Keith Wong  6011891618747196       3880          Ok
# 242      Dennis Dixon     4375220550950       at17          Ok
# 243   Michelle Hardin  3511451626698139       r672          Ok

# %%
df['Tip Quality'].value_counts()
# Out:
# Tip Quality
# Ok          234
# Generous     10
# Name: count, dtype: int64

# %% [markdown]
# <a id='uni'></a>
# ### unique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df['size'].nunique()
# Out:
# 6

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'].nunique()
# Out:
# 2

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['time'].nunique()
# Out:
# 2

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()
# Out:
# 4

# %% [markdown]
# <a id='map'></a>
# ### map

# %%
my_map = {'Dinner':'D','Lunch':'L'}

# %%
df['time'].map(my_map)
# Out:
# 0      D
# 1      D
# 2      D
# 3      D
# 4      D
#       ..
# 239    D
# 240    D
# 241    D
# 242    D
# 243    D
# Name: time, Length: 244, dtype: object

# %%
df['map'] = df['time'].map(my_map)

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality map
# 0  Christy Cunningham  3560325168603410       2959          Ok   D
# 1      Douglas Tucker  4478071379779230       4608          Ok   D
# 2      Travis Walters  6011812112971322       4458          Ok   D
# 3    Nathaniel Harris  4676137647685994       5260          Ok   D
# 4        Tonya Carter  4832732618637221       2251          Ok   D

# %% [markdown]
# <a id='dup'></a>
# ## Duplicates
#
# ### .duplicated() and .drop_duplicates()

# %%
# Returns True for the 1st instance of a duplicated row
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.drop_duplicates(inplace=True)
# or 
# simple_df = simple_df.drop_duplicates()

# %%
simple_df
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# <a id='bet'></a>
# ## between
#
# left: A scalar value that defines the left boundary<br>
# right: A scalar value that defines the right boundary<br>
# inclusive: A String value: 'both','left', 'right', or 'neither'

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID Tip Quality map
# 0  Christy Cunningham  3560325168603410       2959          Ok   D
# 1      Douglas Tucker  4478071379779230       4608          Ok   D
# 2      Travis Walters  6011812112971322       4458          Ok   D
# 3    Nathaniel Harris  4676137647685994       5260          Ok   D
# 4        Tonya Carter  4832732618637221       2251          Ok   D

# %%
df['total_bill'].between(15,20,inclusive='both')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(15,20,inclusive='neither')]
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 12        15.42  1.57    Male     No   Sun  Dinner     2              7.71
# 13        18.43  3.00    Male     No   Sun  Dinner     4              4.61
# 17        16.29  3.71    Male     No   Sun  Dinner     3              5.43
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2              8.14
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID Tip Quality map
# 0    Christy Cunningham  3560325168603410       2959          Ok   D
# 8       Joseph Mcdonald  3522866365840377       6820          Ok   D
# 12      Chad Harrington      577040572932       1300          Ok   D
# 13         Joshua Jones  6011163105616890       2971          Ok   D
# 17         John Pittman  6521340257218708       2998          Ok   D
# ..                  ...               ...        ...         ...  ..
# 225      Whitney Arnold  3579111947217428       6665          Ok   L
# 231         Jason Parks     4812333796161       6334          Ok   D
# 234       Tracy Douglas  4097938155941930       7220          Ok   D
# 242        Dennis Dixon     4375220550950       at17          Ok   D
# 243     Michelle Hardin  3511451626698139       r672          Ok   D
#
# [67 rows x 13 columns]

# %%
df[df['total_bill'].between(15,20,inclusive='left')].shape  # >= 15 and <20
# Out:
# (67, 13)

# %% [markdown]
# # Discussed on 08-Mar-2025

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/tips.csv')

# %% [markdown]
# <a id='sample'></a>
# ## sample

# %%
df.shape
# Out:
# (244, 11)

# %%
df.sample(5)
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 157       25.00  3.75  Female     No   Sun  Dinner     4              6.25
# 143       27.05  5.00  Female     No  Thur   Lunch     6              4.51
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 97        12.03  1.50    Male    Yes   Fri  Dinner     2              6.02
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
#
#              Payer Name         CC Number Payment ID
# 157        Laura Robles   213158685144262    Sun7015
# 143        Regina Jones     4311048695487   Thur6179
# 0    Christy Cunningham  3560325168603410    Sun2959
# 97         Eric Herrera      580116092652    Fri9268
# 172         Larry White    30432617123103    Sun9209

# %%
df.sample(frac=0.1)
# Out:
#      total_bill    tip  gender smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 133       12.26   2.00  Female     No  Thur   Lunch     2              6.13
# 91        22.49   3.50    Male     No   Fri  Dinner     2             11.24
# 28        21.70   4.30    Male     No   Sat  Dinner     2             10.85
# 137       14.15   2.00  Female     No  Thur   Lunch     2              7.08
# 238       35.83   4.67  Female     No   Sat  Dinner     3             11.94
# 81        16.66   3.40    Male     No  Thur   Lunch     2              8.33
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84
# 153       24.55   2.00    Male     No   Sun  Dinner     4              6.14
# 55        19.49   3.51    Male     No   Sun  Dinner     2              9.74
# 19        20.65   3.35    Male     No   Sat  Dinner     3              6.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 234       15.53   3.00    Male    Yes   Sat  Dinner     2              7.76
# 100       11.35   2.50  Female    Yes   Fri  Dinner     2              5.68
# 175       32.90   3.11    Male    Yes   Sun  Dinner     2             16.45
# 127       14.52   2.00  Female     No  Thur   Lunch     2              7.26
# 62        11.02   1.98    Male    Yes   Sat  Dinner     2              5.51
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4              6.47
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 77        27.20   4.00    Male     No  Thur   Lunch     4              6.80
# 112       38.07   4.00    Male     No   Sun  Dinner     3             12.69
# 147       11.87   1.63  Female     No  Thur   Lunch     2              5.94
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 64        17.59   2.64    Male     No   Sat  Dinner     3              5.86
#
#              Payer Name         CC Number Payment ID
# 59          Brian Ortiz  6596453823950595    Sat8139
# 133        Kaitlin Wolf      676348318145   Thur1561
# 91            Earl Horn  6011849326227398    Fri5700
# 28        David Collier  5529694315416009    Sat3697
# 137      Vanessa Morris   213189344156819   Thur3890
# 238      Kimberly Crane      676184013727    Sat9777
# 81       William Martin  4550549048402707   Thur8232
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 153      Todd Patterson  4416804908942159    Sun8670
# 55     Michael Hamilton  6502227786581768    Sun1118
# 19        Timothy Oneal  6568069240986485    Sat9213
# 236       Matthew Myers  3543676378973965    Sat5032
# 234       Tracy Douglas  4097938155941930    Sat7220
# 100          Lori Lynch    38558279384492    Fri4106
# 175     Nathan Reynolds   370307040837149    Sun5109
# 127     Jessica Simmons   213102478792200   Thur1512
# 62          Joseph Hart   180046232326178    Sat2265
# 211      Christopher Li  6011962464150569    Sat6735
# 0    Christy Cunningham  3560325168603410    Sun2959
# 77           John Davis    30344778738589   Thur4924
# 112          Jeff Lopez  3572865915176463     Sun591
# 147  Annette Cunningham      675937746864   Thur4780
# 170       Gregory Clark  5473850968388236    Sat1954
# 64      Michael Johnson  2222114458088108    Sat1667

# %%
244*0.1
# Out:
# 24.400000000000002

# %%
df.sample(frac=0.1).shape
# Out:
# (24, 11)

# %%
dict2 = {'a':[1,2,3,4,5],'b':[10,20,30,40,50],'c':[100,200,300,400,500]}

# %%
df2 = pd.DataFrame(dict2)

# %%
df2
# Out:
#    a   b    c
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df2.sample(20,replace=True,random_state=42) # Over-sampling
# Out:
#    a   b    c
# 3  4  40  400
# 4  5  50  500
# 2  3  30  300
# 4  5  50  500
# 4  5  50  500
# 1  2  20  200
# 2  3  30  300
# 2  3  30  300
# 2  3  30  300
# 4  5  50  500
# 3  4  40  400
# 2  3  30  300
# 4  5  50  500
# 1  2  20  200
# 3  4  40  400
# 1  2  20  200
# 3  4  40  400
# 4  5  50  500
# 0  1  10  100
# 3  4  40  400

# %% [markdown]
# <a id='n'></a>
# ## nlargest and nsmallest

# %%
df.nlargest(4,'tip')
# Out:
#      total_bill    tip gender smoker  day    time  size  price_per_person  \
# 170       50.81  10.00   Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.00   Male     No  Sat  Dinner     4             12.08
# 23        39.42   7.58   Male     No  Sat  Dinner     4              9.86
# 59        48.27   6.73   Male     No  Sat  Dinner     4             12.07
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139

# %%
df.nlargest(5,'price_per_person')
# Out:
#      total_bill    tip gender smoker  day    time  size  price_per_person  \
# 184       40.55   3.00   Male    Yes  Sun  Dinner     2             20.27
# 179       34.63   3.55   Male    Yes  Sun  Dinner     2             17.32
# 170       50.81  10.00   Male    Yes  Sat  Dinner     3             16.94
# 175       32.90   3.11   Male    Yes  Sun  Dinner     2             16.45
# 237       32.83   1.17   Male    Yes  Sat  Dinner     2             16.42
#
#           Payer Name         CC Number Payment ID
# 184      Stephen Cox  3547798222044029    Sun5140
# 179     Brian Bailey   346656312114848    Sun9851
# 170    Gregory Clark  5473850968388236    Sat1954
# 175  Nathan Reynolds   370307040837149    Sun5109
# 237     Thomas Brown  4284722681265508    Sat2929

# %%
df.nlargest(10,'tip').shape
# Out:
# (10, 11)

# %%
df.nsmallest(3,'tip')
# Out:
#      total_bill  tip  gender smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 92    Leah Ramirez  3508911676966392    Fri3780
# 111    Terri Jones  3559221007826887    Sat4801

# %%
df.nsmallest(4,'tip')
# Out:
#      total_bill  tip  gender smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2              6.30
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 92    Leah Ramirez  3508911676966392    Fri3780
# 111    Terri Jones  3559221007826887    Sat4801
# 236  Matthew Myers  3543676378973965    Sat5032

# %%
df.nsmallest(2,'tip')
# Out:
#     total_bill  tip  gender smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455
# 92   Leah Ramirez  3508911676966392    Fri3780

# %%
df.nsmallest(2,['tip','size'])
# Out:
#      total_bill  tip  gender smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 111        7.25  1.0  Female     No  Sat  Dinner     1              7.25
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 111    Terri Jones  3559221007826887    Sat4801
